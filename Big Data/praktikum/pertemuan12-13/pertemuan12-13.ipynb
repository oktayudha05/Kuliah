# %% [markdown]
# ### Pertemuan 12 ###

# %%
import pandas as pd

df = pd.read_csv('dataset-tanaman-padi.csv')
datasetTeratas = df.head(5)

print('5 Dataset sebelum pembersihan:\n', datasetTeratas)

datasetTeratas['Kelembapan'].fillna(datasetTeratas['Kelembapan'].median(), inplace=True)
datasetTeratas['Curah hujan'].fillna(datasetTeratas['Curah hujan'].mean(), inplace=True)
datasetTeratas.dropna(subset=['Provinsi'], inplace=True)

print('setelah pembersihan:\n', datasetTeratas)
# Out:
# 5 Dataset sebelum pembersihan:
#    Provinsi  Tahun   Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0      NaN   1993  1329536.0    323589.0       1627.0       82.00
# 1     Aceh   1994  1299699.0    329041.0          NaN       82.12
# 2     Aceh   1995  1382905.0    339253.0       1476.0         NaN
# 3     Aceh   1996  1419128.0    348223.0       1557.0       83.00
# 4     Aceh   1997  1368074.0    337561.0       1339.0       82.46
#
#    Suhu rata-rata
# 0           26.06
# 1           26.92
# 2           26.27
# 3           26.08
# 4           26.31
# setelah pembersihan:
#    Provinsi  Tahun   Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 1     Aceh   1994  1299699.0    329041.0      1499.75       82.12
# 2     Aceh   1995  1382905.0    339253.0      1476.00       82.29
# 3     Aceh   1996  1419128.0    348223.0      1557.00       83.00
# 4     Aceh   1997  1368074.0    337561.0      1339.00       82.46
#
#    Suhu rata-rata
# 1           26.92
# 2           26.27
# 3           26.08
# 4           26.31
# /tmp/ipykernel_2769/3442606455.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetTeratas['Kelembapan'].fillna(datasetTeratas['Kelembapan'].median(), inplace=True)
# /tmp/ipykernel_2769/3442606455.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasetTeratas['Kelembapan'].fillna(datasetTeratas['Kelembapan'].median(), inplace=True)
# /tmp/ipykernel_2769/3442606455.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datasetTeratas['Curah hujan'].fillna(datasetTeratas['Curah hujan'].mean(), inplace=True)
# /tmp/ipykernel_2769/3442606455.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasetTeratas['Curah hujan'].fillna(datasetTeratas['Curah hujan'].mean(), inplace=True)
# /tmp/ipykernel_2769/3442606455.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datasetTeratas.dropna(subset=['Provinsi'], inplace=True)

# %% [markdown]
# ### Pertemuan 13 ###

# %%
import matplotlib.pyplot as plt

kategori = ['Suhu rata-rata', 'Kelembapan']
nilai = [datasetTeratas['Suhu rata-rata'].mean(), datasetTeratas['Kelembapan'].mean()]

plt.figure(figsize=(5, 3))
plt.bar(kategori, nilai, color='orange')
plt.xlabel('Kategori')
plt.ylabel('Nilai')
plt.title('Bar Chart kategori pada Provinsi Aceh')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='Curah hujan', y='Suhu rata-rata', data=datasetTeratas, color='orange')
plt.title('Hubungan antara Curah hujan dan suhu rata rata')
plt.figure(figsize=(5, 3))
plt.show()
